# %%
import time
import asyncio

async def download_file_async(file_name):
  print(f"開始下載 {file_name}...")
  await asyncio.sleep(2)
  print(f"✅ {file_name} 下載完成")
  return f"{file_name}_data"

async def main_async():
  start = time.time()

  results = await asyncio.gather(
    download_file_async("檔案A.pdf"),
    download_file_async("檔案B.pdf"),
    download_file_async("檔案C.pdf"),
  )

  end = time.time()
  print(f"\n總耗時: {end - start:.2f} 秒")

if __name__ == "__main__":
 await main_async()
# Out:
# 開始下載 檔案A.pdf...
# 開始下載 檔案B.pdf...
# 開始下載 檔案C.pdf...
# ✅ 檔案A.pdf 下載完成
# ✅ 檔案B.pdf 下載完成
# ✅ 檔案C.pdf 下載完成
#
# 總耗時: 2.01 秒

# %%
import asyncio
from playwright.sync_api import async_playwright,Browser,Page

async def main():
    async with async_playwright() as p:
        #啟動瀏覽器
        browser:Browser = await p.chromium.launch()
        page:Page = await browser.new_page()
        await browser.close()
        
await main()
# Out:
# --------------------------------------------------------------------------
# ImportError                              Traceback (most recent call last)
# Cell In[6], line 2
#       1 import asyncio
# ----> 2 from playwright.sync_api import async_playwright,Browser,Page
#       3
#       4 async def main():
#       5     async with async_playwright() as p:
#
# ImportError: cannot import name 'async_playwright' from 'playwright.sync_api' (C:\Users\user\Documents\GitHub\2026_07_13\.venv\Lib\site-packages\playwright\sync_api\__init__.py)

# %%
import os
current_dir = os.path.dirname(os.path.abspath(__file__))
print(current_dir)
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 import os
# ----> 2 current_dir = os.path.dirname(os.path.abspath(__file__))
#       3 print(current_dir)
#
# NameError: name '__file__' is not defined
